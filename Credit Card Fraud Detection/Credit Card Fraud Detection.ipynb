# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
df=pd.read_csv("\Data Science Projects\Credit Card Fraud Detection\creditcard.csv")

# %% [markdown]
# # Data Inspection

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# By above observations, we see no null values in each columns.

# %% [markdown]
# # Check for Duplicates

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df=df.reset_index(drop=True)

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# # Checking the Data is Imbalanced

# %%
count=df["Class"].value_counts()
count
# Out:
# 0    282493
# 1       460
# Name: Class, dtype: int64

# %%
labels=["Legimate","Fraud"]
count.plot(kind="pie",figsize=(8,6),labels=labels)
plt.title("TARGET CLASS - DATA DISTRIBUTION")
plt.ylabel("")
plt.axis("equal")
# Out:
# (-1.099999999936952,
#  1.0999999999969976,
#  -1.099999999790966,
#  1.0999999999820282)

# %% [markdown]
# Therefore, the Data is Imbalanced.
# I will do both Oversampling and Undersampling techniques.
# Compare them and Choose the best one which have high scores.

# %% [markdown]
# # Correlation Matrix

# %%
corr_matrix=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix,annot=True,cmap="coolwarm",fmt=".2f",linewidth=1,xticklabels=True)
plt.title("CORRELATION MATRIX")
plt.show()

# %% [markdown]
# There is no relatively large relationship among the features.
# Let's keep this features as it is.

# %%
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class     1.000000
# V11       0.144192
# V4        0.125975
# V2        0.081465
# V8        0.033618
# V19       0.032107
# V27       0.024123
# V21       0.022106
# V20       0.021827
# V28       0.010075
# Amount    0.005719
# V22       0.005613
# V26       0.003606
# V25       0.002990
# V15      -0.002861
# V13      -0.003959
# V23      -0.006838
# V24      -0.007443
# Time     -0.012518
# V6       -0.042551
# V5       -0.083174
# V9       -0.091031
# V1       -0.091201
# V18      -0.100683
# V7       -0.164610
# V3       -0.175376
# V16      -0.179892
# V10      -0.199209
# V12      -0.242007
# V14      -0.285177
# V17      -0.302410
# Name: Class, dtype: float64

# %% [markdown]
# V11 - Maximum Positive Correlation.
# V17 - Maximum Negative Correlation.

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
df["std_amount"]=StandardScaler().fit_transform(df["Amount"].values.reshape(-1,1))
df["std_time"]=StandardScaler().fit_transform(df["Time"].values.reshape(-1,1))
df.drop(["Amount","Time"],axis=1,inplace=True)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  std_amount  std_time
# ...

# %% [markdown]
# # Separating Features and Target

# %%
X=df.drop("Class",axis=1)
Y=df["Class"]

# %% [markdown]
# # 1] Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler
X_under,Y_under=RandomUnderSampler(random_state=42).fit_resample(X,Y)

# %%
count2=Y_under.value_counts()
count2
# Out:
# 0    460
# 1    460
# Name: Class, dtype: int64

# %% [markdown]
# Now we have Balanced Dataset.

# %%
labels=["Legimate","Fraud"]
count2.plot(kind="pie",figsize=(8,6),labels=labels)
plt.title("TARGET CLASS - DATA DISTRIBUTION",loc="left",fontdict={"size":14})
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # Data Splitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_under,Y_under,test_size=0.25,random_state=42)

# %% [markdown]
# # Modelling
# A] LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report

# MAKE PREDICTIONS ON TEST SET

Y_pred=model.predict(X_test)

# EVALUATING THE MODEL WITH FOLLOWING METRICES

accuracy=accuracy_score(Y_test,Y_pred)
f1=f1_score(Y_test,Y_pred,average="weighted")
precision=precision_score(Y_test,Y_pred,average="weighted")
recall=recall_score(Y_test,Y_pred,average="weighted")
report1=classification_report(Y_test,Y_pred)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9565217391304348
# F1 Score : 0.9564020833402578
# Precision : 0.9576053511705686
# Recall : 0.9565217391304348

# %% [markdown]
# CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(Y_test,Y_pred)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues",annot_kws={"size":16},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()

# %% [markdown]
# B] SUPPORT VECTOR MACHINE

# %%
# NEED TO DO GRIDSEARCH CV

# %%
from sklearn.svm import SVC
model=SVC(kernel="rbf",random_state=42)
model.fit(X_train,Y_train)
# Out:
# SVC(random_state=42)

# %%
# MAKE PREDICTIONS ON TEST SET

Y_pred_svm=model.predict(X_test)

# EVALUATING THE MODEL WITH FOLLOWING METRICES

accuracy=accuracy_score(Y_test,Y_pred_svm)
f1=f1_score(Y_test,Y_pred_svm,average="weighted")
precision=precision_score(Y_test,Y_pred_svm,average="weighted")
recall=recall_score(Y_test,Y_pred_svm,average="weighted")
report2=classification_report(Y_test,Y_pred_svm)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9521739130434783
# F1 Score : 0.951880850907457
# Precision : 0.9560708534621578
# Recall : 0.9521739130434783

# %% [markdown]
# CONFUSION MATRIX

# %%
cm2=confusion_matrix(Y_test,Y_pred_svm)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm2,annot=True,fmt="g",cmap="Blues",annot_kws={"size":16},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()

# %% [markdown]
# C] RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=42)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# MAKE PREDICTIONS ON TEST SET

Y_pred_rf=rf.predict(X_test)

# EVALUATING THE MODEL WITH FOLLOWING METRICES

accuracy=accuracy_score(Y_test,Y_pred_rf)
f1=f1_score(Y_test,Y_pred_rf,average="weighted")
precision=precision_score(Y_test,Y_pred_rf,average="weighted")
recall=recall_score(Y_test,Y_pred_rf,average="weighted")
report3=classification_report(Y_test,Y_pred_rf)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9608695652173913
# F1 Score : 0.9607836398006531
# Precision : 0.9616187301237707
# Recall : 0.9608695652173913

# %% [markdown]
# CONFUSION MATRIX

# %%
cm3=confusion_matrix(Y_test,Y_pred_rf)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm3,annot=True,fmt="g",cmap="Blues",annot_kws={"size":16},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()

# %% [markdown]
# D] XGBOOST

# %%
import xgboost as xgb
from xgboost import XGBClassifier
xgb_classifier=xgb.XGBClassifier(n_estimators=200,learning_rate=0.1,random_state=42,max_depth=7)
xgb_classifier.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# MAKE PREDICTIONS ON TEST SET

Y_pred_xg=xgb_classifier.predict(X_test)

# EVALUATING THE MODEL WITH FOLLOWING METRICES

accuracy=accuracy_score(Y_test,Y_pred_xg)
f1=f1_score(Y_test,Y_pred_xg,average="weighted")
precision=precision_score(Y_test,Y_pred_xg,average="weighted")
recall=recall_score(Y_test,Y_pred_xg,average="weighted")
report4=classification_report(Y_test,Y_pred_xg)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9521739130434783
# F1 Score : 0.9521566174030556
# Precision : 0.9521755693581782
# Recall : 0.9521739130434783

# %% [markdown]
# CONFUSION MATRIX

# %%
cm4=confusion_matrix(Y_test,Y_pred_xg)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm4,annot=True,fmt="g",cmap="Blues",annot_kws={"size":16},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()

# %% [markdown]
# # 2] Over Sampling

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
X_over,Y_over=smote.fit_resample(X,Y)

# %%
count3=Y_over.value_counts()
count3
# Out:
# 0    282493
# 1    282493
# Name: Class, dtype: int64

# %% [markdown]
# Now, we have balanced Dataset.

# %%
plt.figure(figsize=(8,6))

labels=["Legimate","Fraud"]
count3.plot(kind="pie",labels=labels)
plt.title("TARGET CLASS - DATA DISTRIBUTION",fontdict={"size":14},loc="left")
plt.ylabel("")
plt.show()

# %% [markdown]
# # Data Splitting

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_over,Y_over,test_size=0.25,random_state=42)

# %% [markdown]
# # Modelling

# %% [markdown]
# A] RANDOM FOREST

# %%
rf=RandomForestClassifier(random_state=42)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# MAKE PREDICTION ON TEST DATA

Y_pred_rf=rf.predict(X_test)

# EVALUA

accuracy=accuracy_score(Y_test,Y_pred_rf)
f1=f1_score(Y_test,Y_pred_rf,average="weighted")
precision=precision_score(Y_test,Y_pred_rf,average="weighted")
recall=recall_score(Y_test,Y_pred_rf,average="weighted")
report5=classification_report(Y_test,Y_pred_rf)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9999221222397644
# F1 Score : 0.9999221222428559
# Precision : 0.9999221343748963
# Recall : 0.9999221222397644

# %% [markdown]
# CONFUSION MATRIX

# %%
cm=confusion_matrix(Y_test,Y_pred_rf)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm,annot=True,fmt="g",cmap="Blues",annot_kws={"size":14},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()

# %% [markdown]
# B] XGBOOST

# %%
xgb_classifier=XGBClassifier(n_estimators=200,learning_rate=0.1,random_state=42,max_depth=7)
xgb_classifier.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# 

Y_pred_xgb=xgb_classifier.predict(X_test)

#

accuracy=accuracy_score(Y_test,Y_pred_xgb)
f1=f1_score(Y_test,Y_pred_xgb,average="weighted")
precision=precision_score(Y_test,Y_pred_xgb,average="weighted")
recall=recall_score(Y_test,Y_pred_xgb,average="weighted")
report6=classification_report(Y_test,Y_pred_xgb)

print("Accuracy :",accuracy)
print("F1 Score :",f1)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.9997309677373679
# F1 Score : 0.9997309677604268
# Precision : 0.9997311125012588
# Recall : 0.9997309677373679

# %% [markdown]
# CONFUSION MATRIX

# %%
cm=confusion_matrix(Y_test,Y_pred_xgb)

plt.figure(figsize=(8,6))
sns.set(font_scale=1.2)
sns.heatmap(cm,annot=True,fmt="g",cmap="Blues",annot_kws={"size":14},square=True)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("CONFUSION MATRIX")

plt.show()
